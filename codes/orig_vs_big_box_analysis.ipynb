# %% [markdown]
# **Importing libraries**

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# **Setting notebook parameters**

# %%
dpi = 100

# %% [markdown]
# **Reading & printing the assessment file for the original simulation box**

# %%
orig_assess = pd.read_csv('Tables/orig-sim-box/cube_cell_size_assess_orig-sim-box_unrounded.tsv', sep='\t')
orig_assess
# Out:
#     Cell Size  Act Cube Size  Cube Size Set  Clusters   Mean - Vx   Mean - Vy  \
# 0      2000.0       160000.0       160000.0    2473.0 -690.056120 -684.117277
# 1      4000.0       160000.0       160000.0    2473.0 -191.597820 -199.790268
# 2      5000.0       160000.0       160000.0    2473.0 -107.814960 -118.144745
# 3      8000.0       160000.0       160000.0    2473.0  -20.604897  -33.313984
# 4     10000.0       160000.0       160000.0    2473.0    0.307951  -13.621350
# 5     20000.0       160000.0       160000.0    2473.0   33.180959   14.309188
# 6      2000.0       200000.0       200000.0    1928.0 -681.437096 -682.262750
# 7      4000.0       200000.0       200000.0    1928.0 -184.881655 -197.069740
# 8      5000.0       200000.0       200000.0    1928.0 -102.702463 -115.958214
# 9      8000.0       200000.0       208000.0    1825.0  -15.017048  -25.861018
# 10    10000.0       200000.0       200000.0    1928.0    3.879742   -7.700638
# 11    20000.0       200000.0       200000.0    1928.0   36.106923   21.195290
# 12     2000.0       240000.0       240000.0    1486.0 -656.902667 -677.128764
# 13     4000.0       240000.0       240000.0    1486.0 -176.163044 -188.245714
# 14     5000.0       240000.0       240000.0    1486.0  -96.417381 -105.577903
# 15     8000.0       240000.0       240000.0    1486.0  -11.845005  -18.242660
# 16    10000.0       240000.0       240000.0    1486.0    7.360976    1.647750
# 17    20000.0       240000.0       240000.0    1486.0   41.651751   30.254568
# 18     2000.0       280000.0       280000.0    1085.0 -660.827735 -682.664951
# 19     4000.0       280000.0       280000.0    1085.0 -173.346902 -190.621984
# 20     5000.0       280000.0       280000.0    1085.0  -95.842585 -104.413541
# 21     8000.0       280000.0       288000.0    1023.0   -9.902317  -11.203198
# 22    10000.0       280000.0       280000.0    1085.0   11.186287    8.583816
# 23    20000.0       280000.0       280000.0    1085.0   45.850232   38.940219
# 24     2000.0       320000.0       320000.0     782.0 -672.477261 -675.597800
# 25     4000.0       320000.0       320000.0     782.0 -183.710153 -187.505100
# 26     5000.0       320000.0       320000.0     782.0 -102.855597 -103.863905
# 27     8000.0       320000.0       320000.0     782.0  -12.582693  -12.539556
# 28    10000.0       320000.0       320000.0     782.0    8.536317    8.211655
# 29    20000.0       320000.0       320000.0     782.0   41.567413   38.093290
#
#      Mean - Vz     SD - Vx     SD - Vy     SD - Vz    r - Vx    r - Vy  \
# 0  -711.920742  899.684113  892.230276  894.248821  0.349823  0.339718
# 1  -227.874660  408.375891  410.571875  397.031611  0.568861  0.562512
# 2  -142.769203  309.567132  315.656314  300.751346  0.647374  0.637265
# 3   -57.221575  205.307244  221.675626  188.731548  0.751985  0.717598
# 4   -37.782345  184.939938  202.668316  164.448286  0.780378  0.747032
# 5   -12.098356  187.927766  207.272037  172.346100  0.785919  0.760255
# 6  -706.011675  892.283683  890.686065  893.515909  0.357875  0.355954
# 7  -227.755218  401.795999  402.532208  395.105075  0.590965  0.586055
# 8  -143.851251  302.685557  304.963608  294.858261  0.668610  0.657383
# 9   -60.298042  192.835814  207.352281  183.258133  0.777257  0.746992
# 10  -40.734810  172.345249  191.281126  159.569568  0.804460  0.767320
# 11  -15.773064  175.335337  196.718843  165.127992  0.809047  0.778613
# 12 -727.173682  899.149981  901.143455  899.246295  0.381046  0.368212
# 13 -235.831304  404.743566  407.203698  392.627665  0.609093  0.602104
# 14 -149.114105  302.239991  302.565585  289.760869  0.680892  0.676461
# 15  -64.503747  184.190782  200.814498  179.788886  0.796398  0.764459
# 16  -42.734989  162.209366  179.829740  155.277179  0.823323  0.796459
# 17  -17.187359  167.632628  188.741005  163.636382  0.820475  0.801961
# 18 -737.659160  901.542890  902.740060  909.057864  0.380634  0.353608
# 19 -239.810646  408.012438  406.751383  400.534974  0.608542  0.602871
# 20 -150.863784  302.943432  303.918896  293.974730  0.686276  0.678472
# 21  -63.151179  183.959756  193.875970  177.507728  0.798497  0.776566
# 22  -42.913242  159.737423  171.195413  151.542431  0.831378  0.809636
# 23  -17.450071  167.240863  177.281527  161.478721  0.828244  0.819361
# 24 -714.533339  925.510796  915.870327  909.446988  0.351274  0.355138
# 25 -230.316766  417.747148  419.594532  411.536246  0.588757  0.606401
# 26 -144.886605  307.609252  311.282553  300.695579  0.675295  0.684599
# 27  -60.362695  186.055690  192.509717  172.582279  0.793137  0.792111
# 28  -41.681748  161.250581  169.161200  145.972772  0.826863  0.824426
# 29  -17.658068  173.800511  176.322082  158.913011  0.814775  0.836591
#
#       r - Vz
# 0   0.390815
# 1   0.622761
# 2   0.695164
# 3   0.784569
# 4   0.813041
# 5   0.800115
# 6   0.398387
# 7   0.623756
# 8   0.702814
# 9   0.799540
# 10  0.823925
# 11  0.815829
# 12  0.396506
# 13  0.629962
# 14  0.713794
# 15  0.808883
# 16  0.836960
# 17  0.824755
# 18  0.407095
# 19  0.635759
# 20  0.724194
# 21  0.820744
# 22  0.849798
# 23  0.837402
# 24  0.408210
# 25  0.624735
# 26  0.716727
# 27  0.821813
# 28  0.850046
# 29  0.831998

# %% [markdown]
# **Reading & printing the assessment file for the big simulation box**

# %%
big_assess = pd.read_csv('Tables/big-sim-box/cube_cell_size_assess_big-sim-box_unrounded.tsv', sep='\t')
big_assess
# Out:
#     Cell Size  Act Cube Size  Cube Size Set  Clusters   Mean - Vx   Mean - Vy  \
# 0      2000.0       160000.0       160000.0    6080.0 -732.841544 -716.559596
# 1      4000.0       160000.0       160000.0    6080.0 -237.388302 -229.997302
# 2      5000.0       160000.0       160000.0    6080.0 -151.110289 -147.715930
# 3      8000.0       160000.0       160000.0    6080.0  -59.753965  -59.102418
# 4     10000.0       160000.0       160000.0    6080.0  -38.457978  -39.345686
# 5     20000.0       160000.0       160000.0    6080.0   -7.310637  -11.327763
# 6      2000.0       200000.0       200000.0    6080.0 -732.711039 -716.097527
# 7      4000.0       200000.0       200000.0    6080.0 -237.257167 -229.534915
# 8      5000.0       200000.0       200000.0    6080.0 -150.979871 -147.246309
# 9      8000.0       200000.0       208000.0    6080.0  -59.598915  -58.582196
# 10    10000.0       200000.0       200000.0    6080.0  -38.327543  -38.869368
# 11    20000.0       200000.0       200000.0    6080.0   -7.182054  -10.850091
# 12     2000.0       240000.0       240000.0    6080.0 -732.805428 -715.834885
# 13     4000.0       240000.0       240000.0    6080.0 -237.348951 -229.273717
# 14     5000.0       240000.0       240000.0    6080.0 -151.073772 -146.984723
# 15     8000.0       240000.0       240000.0    6080.0  -59.716575  -58.385912
# 16    10000.0       240000.0       240000.0    6080.0  -38.424744  -38.600210
# 17    20000.0       240000.0       240000.0    6080.0   -7.277346  -10.597235
# 18     2000.0       280000.0       280000.0    6080.0 -732.489882 -715.831688
# 19     4000.0       280000.0       280000.0    6080.0 -237.033031 -229.269771
# 20     5000.0       280000.0       280000.0    6080.0 -150.759821 -146.980664
# 21     8000.0       280000.0       288000.0    6080.0  -59.254923  -58.390745
# 22    10000.0       280000.0       280000.0    6080.0  -38.111365  -38.599278
# 23    20000.0       280000.0       280000.0    6080.0   -6.967212  -10.603516
# 24     2000.0       320000.0       320000.0    6080.0 -732.196644 -715.656432
# 25     4000.0       320000.0       320000.0    6080.0 -236.738364 -229.093657
# 26     5000.0       320000.0       320000.0    6080.0 -150.465777 -146.802173
# 27     8000.0       320000.0       320000.0    6080.0  -59.107755  -58.205047
# 28    10000.0       320000.0       320000.0    6080.0  -37.817908  -38.421727
# 29    20000.0       320000.0       320000.0    6080.0   -6.687037  -10.433346
#
#      Mean - Vz     SD - Vx     SD - Vy     SD - Vz    r - Vx    r - Vy  \
# 0  -722.362620  910.184579  902.728096  906.594484  0.352010  0.343018
# 1  -231.016250  415.976127  416.928890  405.245096  0.578263  0.566865
# 2  -148.101802  319.275939  323.291894  304.686308  0.650584  0.637094
# 3   -59.807622  218.808453  222.974096  189.496483  0.748024  0.724920
# 4   -39.778225  200.320743  203.669913  165.721610  0.775370  0.752110
# 5   -13.325932  206.260030  204.755986  173.625185  0.778644  0.766198
# 6  -722.012051  908.531225  900.732580  904.848315  0.361845  0.353286
# 7  -230.667477  412.037195  412.187999  402.187984  0.594649  0.584608
# 8  -147.755768  313.940253  317.184683  300.922408  0.669179  0.657406
# 9   -59.439941  209.379266  212.177376  182.970911  0.772791  0.754547
# 10  -39.428767  191.451752  193.775009  159.173310  0.797209  0.778296
# 11  -12.989533  197.535796  195.021813  168.011248  0.800768  0.794389
# 12 -721.930080  907.250850  899.241448  904.196012  0.368770  0.362421
# 13 -230.587224  408.788135  408.486054  400.768987  0.606481  0.599913
# 14 -147.673643  309.627647  312.171977  299.203247  0.682687  0.674815
# 15  -59.375982  204.030665  206.303539  181.205697  0.785593  0.770338
# 16  -39.345827  184.092343  185.379879  156.170743  0.814005  0.799302
# 17  -12.925292  190.153093  186.687540  165.307571  0.819842  0.815243
# 18 -721.705030  905.991576  897.948502  904.018691  0.374289  0.369325
# 19 -230.360400  406.151857  405.677568  400.258436  0.615786  0.611321
# 20 -147.456031  306.200548  308.326520  298.542489  0.693208  0.687780
# 21  -59.241271  197.872547  199.189797  179.750854  0.799905  0.788239
# 22  -39.125714  178.295908  178.758211  154.707014  0.826611  0.814871
# 23  -12.712593  184.407681  180.232086  163.510332  0.833524  0.830392
# 24 -721.852869  905.280953  897.085122  904.087018  0.378024  0.374464
# 25 -230.509309  404.260661  403.643726  400.149651  0.622222  0.619760
# 26 -147.606164  303.702706  305.594175  298.347386  0.700538  0.697222
# 27  -59.296553  194.807974  195.651523  179.236343  0.806649  0.796966
# 28  -39.273496  173.886100  173.708114  153.902634  0.835782  0.826219
# 29  -12.848727  179.856428  175.184184  162.543566  0.844575  0.841746
#
#       r - Vz
# 0   0.393257
# 1   0.628414
# 2   0.702741
# 3   0.797714
# 4   0.823270
# 5   0.808728
# 6   0.400096
# 7   0.639903
# 8   0.715545
# 9   0.814344
# 10  0.838399
# 11  0.822379
# 12  0.403639
# 13  0.645805
# 14  0.721978
# 15  0.819224
# 16  0.845304
# 17  0.828295
# 18  0.405615
# 19  0.648918
# 20  0.725302
# 21  0.823326
# 22  0.848756
# 23  0.832421
# 24  0.406485
# 25  0.650247
# 26  0.726722
# 27  0.824669
# 28  0.850566
# 29  0.834759

# %% [markdown]
# **Plotting the bar charts to compare Pearson'r for both the boxes**

# %%
for a in ['x', 'y', 'z']:

    plt.figure(figsize = (10, 4), dpi = dpi, facecolor=(1, 1, 1))
    width = 0.25
    plt.bar(orig_assess.index - width/2, orig_assess[f'r - V{a}'], width, label = '640$^3$ h$^{-3}$Mpc$^3$')
    plt.bar(big_assess.index  + width/2, big_assess[f'r - V{a}'],  width, label = '1920$^3$ h$^{-3}$Mpc$^3$');
    plt.ylim(0.3,1)
    plt.ylabel("Pearson's r")
    plt.legend(loc = 'upper left')
    plt.xticks(ticks = orig_assess.index, labels = [f'C: {cell}, B: {box}' for cell, box in zip(orig_assess['Cell Size'], orig_assess['Act Cube Size'])], 
               rotation = 60, fontsize = 6, horizontalalignment = 'right');
    plt.xlabel('Cell and Box Sizes (h$^{-1}$ kpc)')
    plt.title("Original vs Big Simulation Box | Pearson's r for V$_{}$".format(a))

    net = big_assess[f'r - V{a}'] - orig_assess[f'r - V{a}']
    plt.text(0.8, 0.93, f'More r cases: {len(net[net>0])}', transform=plt.gca().transAxes)
    plt.text(0.8, 0.87, f'Less r cases: {len(net[net<0])}', transform=plt.gca().transAxes)
    plt.text(0.8, 0.81, f'Average change: {round(net.mean(),3)}', transform=plt.gca().transAxes)
    plt.tight_layout()
    plt.savefig(f'Plots/orig-vs-big-box/Pearson_r/V{a}.png')

# %% [markdown]
# **Plotting the bar charts to compare the standard deviation in the velocity error for both the boxes**

# %%
for a in ['x', 'y', 'z']:

    plt.figure(figsize = (10, 4), dpi = dpi, facecolor=(1, 1, 1))
    width = 0.25
    plt.bar(orig_assess.index - width/2, orig_assess[f'SD - V{a}'], width, label = '640$^3$ h$^{-3}$Mpc$^3$')
    plt.bar(big_assess.index  + width/2, big_assess[f'SD - V{a}'],  width, label = '1920$^3$ h$^{-3}$Mpc$^3$');
    plt.ylim(0,1200)
    plt.ylabel("SD of error in velocity (km/s)")
    plt.legend(loc = 'upper left')
    plt.xticks(ticks = orig_assess.index, labels = [f'C: {cell}, B: {box}' for cell, box in zip(orig_assess['Cell Size'], orig_assess['Act Cube Size'])], 
               rotation = 60, fontsize = 6, horizontalalignment = 'right');
    plt.xlabel('Cell and Box Sizes (h$^{-1}$ kpc)')
    plt.title("Original vs Big Simulation Box | SD of error in V$_{}$".format(a))

    net = big_assess[f'SD - V{a}'] - orig_assess[f'SD - V{a}']
    plt.text(0.75, 0.93, f'Less SD cases: {len(net[net<0])}', transform=plt.gca().transAxes)
    plt.text(0.75, 0.87, f'More SD cases: {len(net[net>0])}', transform=plt.gca().transAxes)
    plt.text(0.75, 0.81, f'Average change: {round(net.mean(),1)} km/s', transform=plt.gca().transAxes)
    plt.tight_layout()
    plt.savefig(f'Plots/orig-vs-big-box/SD_of_error/V{a}.png')

# %% [markdown]
# **Plotting the bar charts to compare the absolute value of the mean of velocity error for both the boxes**

# %%
for a in ['x', 'y', 'z']:

    plt.figure(figsize = (10, 4), dpi = dpi, facecolor=(1, 1, 1))
    width = 0.25
    plt.bar(orig_assess.index - width/2, abs(orig_assess[f'Mean - V{a}']), width, label = '640$^3$ h$^{-3}$Mpc$^3$')
    plt.bar(big_assess.index  + width/2, abs(big_assess[f'Mean - V{a}']),  width, label = '1920$^3$ h$^{-3}$Mpc$^3$');
    plt.ylim(0, 1000)
    plt.ylabel("Mean error in velocity (km/s)")
    plt.legend(loc = 'upper left')
    plt.xticks(ticks = orig_assess.index, labels = [f'C: {cell}, B: {box}' for cell, box in zip(orig_assess['Cell Size'], orig_assess['Act Cube Size'])], 
               rotation = 60, fontsize = 6, horizontalalignment = 'right');
    plt.xlabel('Cell and Box Sizes (h$^{-1}$ kpc)')
    plt.title("Original vs Big Simulation Box | Mean error for V$_{}$".format(a))

    net = abs(big_assess[f'Mean - V{a}']) - abs(orig_assess[f'Mean - V{a}'])
    plt.text(0.75, 0.93, f'Less abs v cases: {len(net[net<0])}', transform=plt.gca().transAxes)
    plt.text(0.75, 0.87, f'More abs v cases: {len(net[net>0])}', transform=plt.gca().transAxes)
    plt.text(0.75, 0.81, f'Average change: {round(net.mean(),1)} km/s', transform=plt.gca().transAxes)
    plt.tight_layout()
    plt.savefig(f'Plots/orig-vs-big-box/Abs_mean_of_error/V{a}.png')

# %% [markdown]
# **Plotting the bar charts to compare the signed value of the mean of velocity error for both the boxes**

# %%
for a in ['x', 'y', 'z']:

    plt.figure(figsize = (10, 4), dpi = dpi, facecolor=(1, 1, 1))
    width = 0.25
    plt.bar(orig_assess.index - width/2, orig_assess[f'Mean - V{a}'], width, label = '640$^3$ h$^{-3}$Mpc$^3$')
    plt.bar(big_assess.index  + width/2, big_assess[f'Mean - V{a}'],  width, label = '1920$^3$ h$^{-3}$Mpc$^3$');
    plt.ylim(-1000,)
    plt.ylabel("Mean error in velocity (km/s)")
    plt.legend(loc = 'lower left')
    plt.xticks(ticks = orig_assess.index, labels = [f'C: {cell}, B: {box}' for cell, box in zip(orig_assess['Cell Size'], orig_assess['Act Cube Size'])], 
               rotation = 60, fontsize = 6, horizontalalignment = 'right');
    plt.xlabel('Cell and Box Sizes (h$^{-1}$ kpc)')
    plt.title("Original vs Big Simulation Box | Mean error for V$_{}$".format(a))

    net = big_assess[f'Mean - V{a}'] - orig_assess[f'Mean - V{a}']
    plt.text(0.75, 0.15, f'Net v vec +ve cases: {len(net[net>0])}', transform=plt.gca().transAxes)
    plt.text(0.75, 0.09, f'Net v vec -ve cases: {len(net[net<0])}', transform=plt.gca().transAxes)
    plt.text(0.75, 0.03, f'Average change: {round(net.mean(),1)} km/s', transform=plt.gca().transAxes)
    plt.tight_layout()
    plt.savefig(f'Plots/orig-vs-big-box/Signed_mean_of_error/V{a}.png')

# %% [markdown]
# **Conclusion**
# 1. To the credit of big simulation box, Pearson's increases for 67 out of 90 cases but only slightly: 0.003 (Vx), 0.006 (Vy), 0.007 (Vz) on average.
# 2. But to its discredit, standard deviation in the velocity errors also increases in 69 out of 90 cases: 10 km/s (Vx), 2 km/s (Vy) & 3 km/s (Vz) on average.
# 3. Also to it discredit, the absolute value of mean of the velocity errors also increases in 62 out of 90 cases: 35 km/s (Vx) & 27 km/s (Vy) on average; for Vz, the mean decreases, i.e., it's -0.7 km/s. The mean velocity error tend to get more negative in 72 out of 90 cases: -50 km/s (Vx) & -38 km/s; for Vz, the mean gets positive, i.e., it's 0.7 km/s.
#
# Hence, if Pearson's r is the most important indicator of the goodness of the simulation box, the big simulation box should be used. Else, if standard deviation & Mean of the error are important, the original simulation box should be preferred.
