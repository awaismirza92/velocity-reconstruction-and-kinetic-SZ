# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
greater_than = 10

# %%
# %%time

data_address = '../Data/'
df_gal = pd.read_csv(data_address + f'massive_galaxies_10_{greater_than}.csv') 

df_gal.describe()
# Out:
# CPU times: user 3.63 s, sys: 268 ms, total: 3.89 s
# Wall time: 3.89 s
#            x[kpc/h]      y[kpc/h]      z[kpc/h]     m[Msol/h]          host  \
# count  3.678431e+06  3.678431e+06  3.678431e+06  3.678431e+06  3.678431e+06
# mean   3.231623e+05  3.213125e+05  3.203307e+05  4.091361e+10  5.225362e+04
# std    1.850387e+05  1.834972e+05  1.836340e+05  8.963719e+10  1.437019e+04
# min    2.472523e-02  4.139575e-02  1.757775e-01  1.000010e+10  0.000000e+00
# 25%    1.614168e+05  1.635298e+05  1.616021e+05  1.731070e+10  5.723700e+04
# 50%    3.277754e+05  3.255006e+05  3.202183e+05  2.291080e+10  5.723700e+04
# 75%    4.823795e+05  4.765793e+05  4.785357e+05  3.694520e+10  5.723700e+04
# max    6.399998e+05  6.399998e+05  6.399998e+05  1.077460e+13  5.723700e+04
#
#         dist[kpc/h]      vx[km/s]      vy[km/s]      vz[km/s]
# count  3.678431e+06  3.678431e+06  3.678431e+06  3.678431e+06
# mean   4.724418e+01 -3.848629e-01  2.138708e-01  7.666311e-02
# std    1.686937e+02  3.562749e+02  3.498227e+02  3.336928e+02
# min    0.000000e+00 -3.890077e+03 -3.448558e+03 -3.414454e+03
# 25%    0.000000e+00 -2.255566e+02 -2.198906e+02 -2.071114e+02
# 50%    0.000000e+00 -5.377200e+00  2.296509e+00 -5.732940e-01
# 75%    0.000000e+00  2.205335e+02  2.203445e+02  2.064592e+02
# max    2.689410e+03  3.089348e+03  3.447494e+03  3.245993e+03

# %%
df_clusters_subset = pd.read_csv(data_address + 'massive_clusters.csv', 
                          usecols = ['UID', 'x[kpc/h]', 'y[kpc/h]', 'z[kpc/h]', 
                                     'm500c[Msol/h]', 'vx[km/s]', 'vy[km/s]', 'vz[km/s]'    ])  #massive_clusters.csv contains clusters with M_500c greater than 10^13.5 h^{-1} M_sun as done by Tanimura et al. (2020)

df_clusters_subset.describe()
# Out:
#                 UID       x[kpc/h]       y[kpc/h]       z[kpc/h]  \
# count   6080.000000    6080.000000    6080.000000    6080.000000
# mean    3488.193257  326416.401838  322055.402286  321308.240244
# std     2329.428037  186021.550694  182650.899538  183665.854310
# min        0.000000      19.163288     152.653880      87.370949
# 25%     1534.750000  160978.575000  164793.430000  161863.925000
# 50%     3195.500000  338884.565000  333274.345000  322110.075000
# 75%     5159.250000  486227.747500  473556.765000  478893.610000
# max    11472.000000  639887.560000  639933.380000  639848.380000
#
#        m500c[Msol/h]     vx[km/s]     vy[km/s]     vz[km/s]
# count   6.080000e+03  6080.000000  6080.000000  6080.000000
# mean    6.356245e+13     2.109102    -1.647297    -4.296055
# std     4.851698e+13   316.064539   306.226537   286.454388
# min     3.162340e+13 -1179.530000 -1163.520000 -1104.790000
# 25%     3.795035e+13  -200.229000  -205.139250  -190.806000
# 50%     4.801630e+13    -3.619450     1.969450    -8.055475
# 75%     6.945502e+13   206.816750   207.755750   181.532000
# max     7.438200e+14  1197.640000  1164.960000  1201.260000

# %%
mask = df_gal['host'].isin(df_clusters_subset['UID'])
df_gal_around_6k_clus = df_gal[mask]

df_gal_around_6k_clus.describe()
# Out:
#             x[kpc/h]       y[kpc/h]       z[kpc/h]     m[Msol/h]  \
# count  156537.000000  156537.000000  156537.000000  1.565370e+05
# mean   329388.897362  323514.404200  322380.041495  1.020323e+11
# std    187282.271526  181355.877716  183801.083042  3.349758e+11
# min        14.773047       0.307792       0.260974  1.000010e+10
# 25%    161274.690000  168091.720000  163842.580000  1.811140e+10
# 50%    346309.380000  337680.690000  321722.780000  2.693140e+10
# 75%    492035.030000  471563.120000  478832.250000  5.201870e+10
# max    639992.810000  639993.380000  639989.000000  1.077460e+13
#
#                 host    dist[kpc/h]       vx[km/s]       vy[km/s]  \
# count  156537.000000  156537.000000  156537.000000  156537.000000
# mean     2508.103956     573.212999       1.358069       2.963645
# std      2207.602807     382.837802     628.967822     626.371526
# min         0.000000       0.000000   -3890.077400   -3448.557900
# 25%       647.000000     270.856000    -394.224000    -390.289060
# 50%      1900.000000     523.181000      -0.414866      -0.112036
# 75%      3907.000000     824.105000     398.592380     395.963710
# max     11472.000000    2689.410000    3089.348100    3447.494100
#
#             vz[km/s]
# count  156537.000000
# mean       -1.869600
# std       616.076356
# min     -3414.453600
# 25%      -388.256130
# 50%        -3.110570
# 75%       385.057400
# max      3245.993200

# %%
dpi = 120
plt.figure(dpi = dpi)
plt.hist(df_gal_around_6k_clus['host'], bins = max(df_gal_around_6k_clus['host']), 
         ec = 'C0')
# plt.yscale('log')
plt.xlabel('Cluster ID')
plt.ylabel('No. of galaxies');

# %%
print(df_gal_around_6k_clus.groupby('host').size().mean())

print(df_gal_around_6k_clus.groupby('host').size().sum())
print(len(df_gal_around_6k_clus))
# Out:
# 25.74621710526316
# 156537
# 156537

# %%
dpi = 120
plt.figure(dpi = dpi)

ser_gal_count = df_gal_around_6k_clus.groupby('host').size()
plt.bar(ser_gal_count.index, height = ser_gal_count,ec = 'C0');

# plt.yscale('log')
plt.xlabel('Cluster ID')
plt.ylabel('No. of galaxies');
plt.title('Galaxies with Mass > 10$^{' + f'{greater_than}' + '}$ M$_{\odot}$h$^{\mathrm{-1}}$');

print('Mean no of galaxies: ', round(df_gal_around_6k_clus.groupby('host').size().mean(), 2))
# print('Mean distance of galaxies: ', round(df_gal_around_6k_clus.groupby('dist[kpc/h]').size().mean(), 2), 'kpc/h')
print('Mean distance of galaxies: ', round(df_gal_around_6k_clus['dist[kpc/h]'].mean(), 2), 'kpc/h')
# Out:
# Mean no of galaxies:  25.75
# Mean distance of galaxies:  573.21 kpc/h
